# %%
cd "./diff_class(class vector no-fixed)/hamster2rabbit"
# Out:
# [Errno 2] No such file or directory: './diff_class(class vector no-fixed)/hamster2rabbit'
# /Users/xuejiaxin/Dropbox/My Mac (Jiaxin的MacBook Pro)/Documents/GitHub/latent/pytorch-pretrained-BigGAN/diff_class(class vector no-fixed)/hamster2rabbit

# %%
# %load_ext autoreload
# %autoreload 2

# target image
import torch
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample,
                                       save_as_images, display_in_terminal, one_hot_from_int)
import logging


logging.basicConfig(level=logging.INFO)

model = BigGAN.from_pretrained('biggan-deep-128')

truncation = 0.5
#class_vector = one_hot_from_names(["dog"], batch_size=1)
class_vector = one_hot_from_int(294)
noise_vector = truncated_noise_sample(truncation=truncation, batch_size=1, seed = 10)

noise_vector = torch.from_numpy(noise_vector)
class_vector = torch.from_numpy(class_vector)


with torch.no_grad():
    output = model(noise_vector, class_vector, truncation)

save_as_images(output, "rabbit_target")
# Out:
# INFO:pytorch_pretrained_biggan.model:loading model biggan-deep-128 from cache at /Users/xuejiaxin/.pytorch_pretrained_biggan/6371c3777477e4e75187da1b9b526561aac3134f38c7299a3438009ae560e20d.3434ebdfa74a8c17e0e56061cfd905fa163c92f110e88df77b47da6ce9910b48
# INFO:pytorch_pretrained_biggan.model:Model config {
#   "attention_layer_position": 8,
#   "channel_width": 128,
#   "class_embed_dim": 128,
#   "eps": 0.0001,
#   "layers": [
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       16
#     ],
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       8
#     ],
#     [
#       false,
#       8,
#       8
#     ],
#     [
#       true,
#       8,
#       4
#     ],
#     [
#       false,
#       4,
#       4
#     ],
#     [
#       true,
#       4,
#       2
#     ],
#     [
#       false,
#       2,
#       2
#     ],
#     [
#       true,
#       2,
#       1
#     ]
#   ],
#   "n_stats": 51,
#   "num_classes": 1000,
#   "output_dim": 128,
#   "z_dim": 128
# }
#
# INFO:pytorch_pretrained_biggan.utils:Saving image to rabbit_target_0.png

# %%
from PIL import Image
from torchvision import transforms
import torch
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample,
                                       save_as_images, display_in_terminal, one_hot_from_int)
import logging


logging.basicConfig(level=logging.INFO)

model = BigGAN.from_pretrained('biggan-deep-128')

img = Image.open("./rabbit_target.jpg")
output = transforms.ToTensor()(img).unsqueeze_(0)
# Out:
# INFO:pytorch_pretrained_biggan.model:loading model biggan-deep-128 from cache at /Users/xuejiaxin/.pytorch_pretrained_biggan/6371c3777477e4e75187da1b9b526561aac3134f38c7299a3438009ae560e20d.3434ebdfa74a8c17e0e56061cfd905fa163c92f110e88df77b47da6ce9910b48
# INFO:pytorch_pretrained_biggan.model:Model config {
#   "attention_layer_position": 8,
#   "channel_width": 128,
#   "class_embed_dim": 128,
#   "eps": 0.0001,
#   "layers": [
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       16
#     ],
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       8
#     ],
#     [
#       false,
#       8,
#       8
#     ],
#     [
#       true,
#       8,
#       4
#     ],
#     [
#       false,
#       4,
#       4
#     ],
#     [
#       true,
#       4,
#       2
#     ],
#     [
#       false,
#       2,
#       2
#     ],
#     [
#       true,
#       2,
#       1
#     ]
#   ],
#   "n_stats": 51,
#   "num_classes": 1000,
#   "output_dim": 128,
#   "z_dim": 128
# }

# %%
from torchvision.models import squeezenet1_0
from tqdm import trange
from torch import nn

DEVICE = 'cpu'
model = model.eval().to(DEVICE)


semantic_model = squeezenet1_0(pretrained=True).to(DEVICE)
semantic_model.classifier = torch.nn.Sequential(
    torch.nn.Flatten()
    )
semantic_model = semantic_model.eval()

soft_max = nn.Softmax(dim = 1)
cos_sim = nn.CosineSimilarity(dim=1, eps=1e-6)

truncation = 0.5
noise = truncated_noise_sample(truncation=truncation, batch_size=1, seed=10)
noise = torch.nn.Parameter(torch.tensor(noise, requires_grad=True).float().to(DEVICE))

class_vector = one_hot_from_int(333)
class_vector = torch.nn.Parameter(torch.tensor(class_vector, requires_grad=True).float().to(DEVICE))

optim = torch.optim.Adam([noise, class_vector], lr=0.05)

save_as_images(model(noise, class_vector, truncation), f"start")

L = []
L_pixel = []
L_semantic = []

for iteration in trange(0, 301):
    optim.zero_grad()

    #output_1 = torch.nn.functional.gumbel_softmax(class_vector, tau=1, hard=True)
    output_1 = soft_max(class_vector)

    y_hat = model(noise, output_1, truncation)

    #semantic_loss = -((semantic_model(y_hat) - semantic_model(output)) ** 2).mean() ** .5 
    semantic_loss = -cos_sim(semantic_model(y_hat), semantic_model(output))
    L_semantic.append(semantic_loss.item())

    pixel_loss = abs(y_hat - output).mean()
    L_pixel.append(pixel_loss.item())

    loss = 100 * semantic_loss + 60 * pixel_loss
    L.append(loss.item())

    loss.backward()
    optim.step()


    if iteration % 1 == 0:
        print(output_1.argmax())
        save_as_images(y_hat, f"hamster2rabbit_{iteration}")
# Out:
# INFO:pytorch_pretrained_biggan.utils:Saving image to start_0.png
#   0%|          | 0/301 [00:00<?, ?it/s]INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_0_0.png
#   0%|          | 1/301 [00:06<32:02,  6.41s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_1_0.png
#   1%|          | 2/301 [00:12<31:40,  6.36s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_2_0.png
#   1%|          | 3/301 [00:17<30:03,  6.05s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_3_0.png
#   1%|▏         | 4/301 [00:23<28:58,  5.85s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_4_0.png
#   2%|▏         | 5/301 [00:28<28:02,  5.69s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_5_0.png
#   2%|▏         | 6/301 [00:32<24:48,  5.04s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_6_0.png
#   2%|▏         | 7/301 [00:35<22:30,  4.59s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_7_0.png
#   3%|▎         | 8/301 [00:39<21:05,  4.32s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_8_0.png
#   3%|▎         | 9/301 [00:42<19:17,  3.96s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_9_0.png
#   3%|▎         | 10/301 [00:46<19:29,  4.02s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_10_0.png
#   4%|▎         | 11/301 [00:53<23:03,  4.77s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_11_0.png
#   4%|▍         | 12/301 [00:57<21:48,  4.53s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_12_0.png
#   4%|▍         | 13/301 [01:01<21:01,  4.38s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_13_0.png
#   5%|▍         | 14/301 [01:05<20:29,  4.28s/it]tensor(333)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_14_0.png
#   5%|▍         | 15/301 [01:09<20:26,  4.29s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_15_0.png
#   5%|▌         | 16/301 [01:13<20:02,  4.22s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_16_0.png
#   6%|▌         | 17/301 [01:17<19:35,  4.14s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_17_0.png
#   6%|▌         | 18/301 [01:21<19:22,  4.11s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_18_0.png
#   6%|▋         | 19/301 [01:25<19:10,  4.08s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_19_0.png
#   7%|▋         | 20/301 [01:29<19:10,  4.10s/it]tensor(723)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit
/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_277_0.png
#  92%|█████████▏| 278/301 [19:35<01:11,  3.11s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_278_0.png
#  93%|█████████▎| 279/301 [19:39<01:09,  3.16s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_279_0.png
#  93%|█████████▎| 280/301 [19:42<01:06,  3.18s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_280_0.png
#  93%|█████████▎| 281/301 [19:45<01:02,  3.14s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_281_0.png
#  94%|█████████▎| 282/301 [19:48<00:59,  3.15s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_282_0.png
#  94%|█████████▍| 283/301 [19:51<00:57,  3.19s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_283_0.png
#  94%|█████████▍| 284/301 [19:54<00:54,  3.18s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_284_0.png
#  95%|█████████▍| 285/301 [19:58<00:51,  3.23s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_285_0.png
#  95%|█████████▌| 286/301 [20:01<00:48,  3.24s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_286_0.png
#  95%|█████████▌| 287/301 [20:04<00:45,  3.24s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_287_0.png
#  96%|█████████▌| 288/301 [20:08<00:42,  3.29s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_288_0.png
#  96%|█████████▌| 289/301 [20:11<00:39,  3.27s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_289_0.png
#  96%|█████████▋| 290/301 [20:14<00:35,  3.22s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_290_0.png
#  97%|█████████▋| 291/301 [20:17<00:32,  3.26s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_291_0.png
#  97%|█████████▋| 292/301 [20:21<00:29,  3.26s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_292_0.png
#  97%|█████████▋| 293/301 [20:24<00:26,  3.27s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_293_0.png
#  98%|█████████▊| 294/301 [20:27<00:23,  3.35s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_294_0.png
#  98%|█████████▊| 295/301 [20:31<00:19,  3.33s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_295_0.png
#  98%|█████████▊| 296/301 [20:35<00:18,  3.73s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_296_0.png
#  99%|█████████▊| 297/301 [20:40<00:16,  4.10s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_297_0.png
#  99%|█████████▉| 298/301 [20:47<00:14,  4.91s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_298_0.png
#  99%|█████████▉| 299/301 [20:56<00:11,  5.98s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_299_0.png
# 100%|█████████▉| 300/301 [21:10<00:08,  8.43s/it]tensor(403)
# INFO:pytorch_pretrained_biggan.utils:Saving image to hamster2rabbit_300_0.png
# 100%|██████████| 301/301 [21:19<00:00,  4.25s/it]tensor(403)

# %%
import matplotlib.pyplot as plt


plt.plot(L)
plt.plot([x*25 for x in L_pixel], 'r')
plt.plot([x for x in L_semantic], 'b')

plt.show()

# %%
target = y_hat.clone().detach()
save_as_images(target, "target")

noise_fixed = noise.clone().detach()

# %%
from torchvision.models import squeezenet1_0
from tqdm import trange
from random import randint, seed

DEVICE = 'cpu'
model = model.eval().to(DEVICE)


semantic_model = squeezenet1_0(pretrained=True).to(DEVICE)
semantic_model.classifier = torch.nn.Sequential(
    torch.nn.Flatten()
    )
semantic_model = semantic_model.eval()

soft_max = torch.nn.Softmax(dim = 1)
cos_sim = torch.nn.CosineSimilarity(dim=1, eps=1e-6)

truncation = 0.5

seed(0)
class_find = one_hot_from_int(randint(0,1001))
class_find = torch.nn.Parameter(torch.tensor(class_find, requires_grad=True).float().to(DEVICE))

optim_class = torch.optim.Adam([class_find], lr=0.1)

save_as_images(model(noise_fixed, class_find, truncation), f"start_refind")

L = []
L_pixel = []
L_semantic = []

for iteration in trange(0, 401):
    optim_class.zero_grad()

    #output_1 = soft_max(class_find)
    output_1 = torch.nn.functional.gumbel_softmax(class_find, tau=1, hard=True)

    y_hat = model(noise_fixed, output_1, truncation)

    semantic_loss_1 = -((semantic_model(y_hat) - semantic_model(target)) ** 2).mean() ** .5 
    #semantic_loss = -cos_sim(semantic_model(y_hat), semantic_model(output))
    L_semantic.append(semantic_loss_1.item())

    pixel_loss_1 = abs(y_hat - target).mean()
    L_pixel.append(pixel_loss_1.item())

    loss_1 = semantic_loss_1 + 20 * pixel_loss_1
    L.append(loss_1.item())

    loss_1.backward(retain_graph=True)
    optim_class.step()


    if iteration % 1 == 0:
        print(output_1.argmax())
        save_as_images(y_hat, f"recognize_{iteration}")
