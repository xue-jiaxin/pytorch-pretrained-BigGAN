# %%
cd "./diff_class(class vector fixed)/cat2tiger_semantic_like"
# Out:
# /Users/xuejiaxin/Dropbox/My Mac (Jiaxin的MacBook Pro)/Documents/GitHub/latent/pytorch-pretrained-BigGAN/diff_class(class vector fixed)/cat2tiger_semantic_like

# %%
# %load_ext autoreload
# %autoreload 2

# target image
import torch
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample,
                                       save_as_images, display_in_terminal, one_hot_from_int)
import logging


logging.basicConfig(level=logging.INFO)

model = BigGAN.from_pretrained('biggan-deep-128')

truncation = 0.5
#class_vector = one_hot_from_names(["airliner"], batch_size=1)
class_vector = one_hot_from_int(292)
noise_vector = truncated_noise_sample(truncation=truncation, batch_size=1, seed = 29)

noise_vector = torch.from_numpy(noise_vector)
class_vector = torch.from_numpy(class_vector)


with torch.no_grad():
    output = model(noise_vector, class_vector, truncation)

save_as_images(output, "tiger_target")
# Out:
# INFO:pytorch_pretrained_biggan.model:loading model biggan-deep-128 from cache at /Users/xuejiaxin/.pytorch_pretrained_biggan/6371c3777477e4e75187da1b9b526561aac3134f38c7299a3438009ae560e20d.3434ebdfa74a8c17e0e56061cfd905fa163c92f110e88df77b47da6ce9910b48
# INFO:pytorch_pretrained_biggan.model:Model config {
#   "attention_layer_position": 8,
#   "channel_width": 128,
#   "class_embed_dim": 128,
#   "eps": 0.0001,
#   "layers": [
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       16
#     ],
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       8
#     ],
#     [
#       false,
#       8,
#       8
#     ],
#     [
#       true,
#       8,
#       4
#     ],
#     [
#       false,
#       4,
#       4
#     ],
#     [
#       true,
#       4,
#       2
#     ],
#     [
#       false,
#       2,
#       2
#     ],
#     [
#       true,
#       2,
#       1
#     ]
#   ],
#   "n_stats": 51,
#   "num_classes": 1000,
#   "output_dim": 128,
#   "z_dim": 128
# }
#
# INFO:pytorch_pretrained_biggan.utils:Saving image to tiger_target_0.png

# %%
from PIL import Image
from torchvision import transforms
import torch
from pytorch_pretrained_biggan import (BigGAN, one_hot_from_names, truncated_noise_sample,
                                       save_as_images, display_in_terminal, one_hot_from_int)
import logging


logging.basicConfig(level=logging.INFO)

model = BigGAN.from_pretrained('biggan-deep-128')

img = Image.open("./tiger_target_1.jpg")
output = transforms.ToTensor()(img).unsqueeze_(0)
# Out:
# INFO:pytorch_pretrained_biggan.model:loading model biggan-deep-128 from cache at /Users/xuejiaxin/.pytorch_pretrained_biggan/6371c3777477e4e75187da1b9b526561aac3134f38c7299a3438009ae560e20d.3434ebdfa74a8c17e0e56061cfd905fa163c92f110e88df77b47da6ce9910b48
# INFO:pytorch_pretrained_biggan.model:Model config {
#   "attention_layer_position": 8,
#   "channel_width": 128,
#   "class_embed_dim": 128,
#   "eps": 0.0001,
#   "layers": [
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       16
#     ],
#     [
#       false,
#       16,
#       16
#     ],
#     [
#       true,
#       16,
#       8
#     ],
#     [
#       false,
#       8,
#       8
#     ],
#     [
#       true,
#       8,
#       4
#     ],
#     [
#       false,
#       4,
#       4
#     ],
#     [
#       true,
#       4,
#       2
#     ],
#     [
#       false,
#       2,
#       2
#     ],
#     [
#       true,
#       2,
#       1
#     ]
#   ],
#   "n_stats": 51,
#   "num_classes": 1000,
#   "output_dim": 128,
#   "z_dim": 128
# }

# %%
from torchvision.models import squeezenet1_0
from tqdm import trange
from torch import nn

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
model = model.eval().to(DEVICE)


semantic_model = squeezenet1_0(pretrained=True).to(DEVICE)
semantic_model.classifier = torch.nn.Sequential(
    torch.nn.Flatten()
    )
semantic_model = semantic_model.eval()

soft_max = nn.Softmax(dim = 1)
cos_sim = nn.CosineSimilarity(dim=1, eps=1e-6)

truncation = 0.5
noise = truncated_noise_sample(truncation=truncation, batch_size=1, seed=1)
noise = torch.nn.Parameter(torch.tensor(noise, requires_grad=True).float().to(DEVICE))
noise_optim = torch.optim.Adam([noise], lr=0.02)

#class_vector = one_hot_from_int(333)
class_vector = one_hot_from_names(['tiger cat'], batch_size=1)
class_vector = torch.from_numpy(class_vector)

L = []
L_pixel = []
L_semantic = []

for iteration in trange(0, 201):
    noise_optim.zero_grad()

    y_hat = model(noise, class_vector, truncation)

    #semantic_loss = -((semantic_model(y_hat) - semantic_model(output)) ** 2).mean() ** .5
    semantic_loss =  cos_sim(semantic_model(y_hat), semantic_model(output))
    L_semantic.append(semantic_loss.item())

    pixel_loss = abs(y_hat - output).mean()
    L_pixel.append(pixel_loss.item())

    loss = 100*semantic_loss + 20 * pixel_loss
    L.append(loss.item())

    loss.backward()
    noise_optim.step()

    if iteration % 1 == 0:
        save_as_images(y_hat, f"cat2tiger_{iteration}")
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_0_0.png
#   0%|          | 1/201 [00:02<09:26,  2.83s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_1_0.png
#   1%|          | 2/201 [00:05<09:26,  2.85s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_2_0.png
#   1%|▏         | 3/201 [00:08<09:36,  2.91s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_3_0.png
#   2%|▏         | 4/201 [00:11<09:28,  2.89s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_4_0.png
#   2%|▏         | 5/201 [00:14<09:26,  2.89s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_5_0.png
#   3%|▎         | 6/201 [00:17<09:56,  3.06s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_6_0.png
#   3%|▎         | 7/201 [00:23<12:32,  3.88s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_7_0.png
#   4%|▍         | 8/201 [00:27<11:53,  3.69s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_8_0.png
#   4%|▍         | 9/201 [00:31<12:35,  3.93s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_9_0.png
#   5%|▍         | 10/201 [00:34<11:32,  3.62s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_10_0.png
#   5%|▌         | 11/201 [00:38<12:21,  3.90s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_11_0.png
#   6%|▌         | 12/201 [00:44<13:33,  4.31s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_12_0.png
#   6%|▋         | 13/201 [00:48<13:49,  4.41s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_13_0.png
#   7%|▋         | 14/201 [00:51<12:25,  3.98s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_14_0.png
#   7%|▋         | 15/201 [00:54<11:15,  3.63s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_15_0.png
#   8%|▊         | 16/201 [00:57<10:19,  3.35s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_16_0.png
#   8%|▊         | 17/201 [01:00<09:58,  3.25s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_17_0.png
#   9%|▉         | 18/201 [01:02<09:18,  3.05s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_18_0.png
#   9%|▉         | 19/201 [01:05<08:43,  2.88s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_19_0.png
#  10%|▉         | 20/201 [01:08<08:24,  2.79s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_20_0.png
#  10%|█         | 21/201 [01:10<08:13,  2.74s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_21_0.png
#  11%|█         | 22/201 [01:13<08:14,  2.76s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_22_0.png
#  11%|█▏        | 23/201 [01:15<07:58,  2.69s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_23_0.png
#  12%|█▏        | 24/201 [01:18<07:53,  2.67s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_24_0.png
#  12%|█▏        | 25/201 [01:21<07:43,  2.64s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_25_0.png
#  13%|█▎        | 26/201 [01:24<08:20,  2.86s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_26_0.png
#  13%|█▎        | 27/201 [01:27<08:00,  2.76s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_27_0.png
#  14%|█▍        | 28/201 [01:29<07:47,  2.70s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_28_0.png
#  14%|█▍        | 29/201 [01:32<07:35,  2.65s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_29_0.png
#  15%|█▍        | 30/201 [01:34<07:28,  2.62s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_30_0.png
#  15%|█▌        | 31/201 [01:37<07:48,  2.75s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_31_0.png
#  16%|█▌        | 32/201 [01:40<07:56,  2.82s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_32_0.png
#  16%|█▋        | 33/201 [01:46<10:16,  3.67s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_33_0.png
#  17%|█▋        | 34/201 [01:49<09:34,  3.44s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_34_0.png
#  17%|█▋        | 35/201 [01:52<09:10,  3.32s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_35_0.png
#  18%|█▊        | 36/201 [01:55<09:04,  3.30s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_36_0.png
#  18%|█▊        | 37/201 [02:01<11:30,  4.21s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger
/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_165_0.png
#  83%|████████▎ | 166/201 [09:25<01:47,  3.07s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_166_0.png
#  83%|████████▎ | 167/201 [09:29<01:48,  3.18s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_167_0.png
#  84%|████████▎ | 168/201 [09:32<01:47,  3.25s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_168_0.png
#  84%|████████▍ | 169/201 [09:35<01:41,  3.17s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_169_0.png
#  85%|████████▍ | 170/201 [09:38<01:36,  3.11s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_170_0.png
#  85%|████████▌ | 171/201 [09:41<01:29,  2.99s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_171_0.png
#  86%|████████▌ | 172/201 [09:44<01:24,  2.91s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_172_0.png
#  86%|████████▌ | 173/201 [09:47<01:21,  2.93s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_173_0.png
#  87%|████████▋ | 174/201 [09:51<01:32,  3.42s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_174_0.png
#  87%|████████▋ | 175/201 [09:55<01:32,  3.57s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_175_0.png
#  88%|████████▊ | 176/201 [09:58<01:23,  3.32s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_176_0.png
#  88%|████████▊ | 177/201 [10:01<01:16,  3.20s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_177_0.png
#  89%|████████▊ | 178/201 [10:04<01:10,  3.05s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_178_0.png
#  89%|████████▉ | 179/201 [10:07<01:07,  3.07s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_179_0.png
#  90%|████████▉ | 180/201 [10:09<01:03,  3.00s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_180_0.png
#  90%|█████████ | 181/201 [10:12<00:58,  2.94s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_181_0.png
#  91%|█████████ | 182/201 [10:15<00:54,  2.87s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_182_0.png
#  91%|█████████ | 183/201 [10:18<00:52,  2.90s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_183_0.png
#  92%|█████████▏| 184/201 [10:21<00:49,  2.88s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_184_0.png
#  92%|█████████▏| 185/201 [10:23<00:44,  2.80s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_185_0.png
#  93%|█████████▎| 186/201 [10:26<00:40,  2.73s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_186_0.png
#  93%|█████████▎| 187/201 [10:29<00:38,  2.78s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_187_0.png
#  94%|█████████▎| 188/201 [10:32<00:35,  2.76s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_188_0.png
#  94%|█████████▍| 189/201 [10:34<00:32,  2.74s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_189_0.png
#  95%|█████████▍| 190/201 [10:37<00:29,  2.69s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_190_0.png
#  95%|█████████▌| 191/201 [10:40<00:26,  2.68s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_191_0.png
#  96%|█████████▌| 192/201 [10:42<00:23,  2.63s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_192_0.png
#  96%|█████████▌| 193/201 [10:46<00:23,  2.90s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_193_0.png
#  97%|█████████▋| 194/201 [10:48<00:19,  2.85s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_194_0.png
#  97%|█████████▋| 195/201 [10:51<00:16,  2.78s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_195_0.png
#  98%|█████████▊| 196/201 [10:54<00:13,  2.75s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_196_0.png
#  98%|█████████▊| 197/201 [10:56<00:10,  2.69s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_197_0.png
#  99%|█████████▊| 198/201 [11:00<00:08,  2.91s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_198_0.png
#  99%|█████████▉| 199/201 [11:03<00:06,  3.05s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_199_0.png
# 100%|█████████▉| 200/201 [11:08<00:03,  3.62s/it]INFO:pytorch_pretrained_biggan.utils:Saving image to cat2tiger_200_0.png
# 100%|██████████| 201/201 [11:13<00:00,  3.35s/it]

# %%
import matplotlib.pyplot as plt


plt.plot( L, color = "grey", label = "loss")
plt.plot( [x*30 for x in L_pixel], color = 'red', label = "pixel loss")
plt.plot( [x*100 for x in L_semantic], color = 'blue', label = "semantic loss")


plt.xlabel('iteration')
plt.legend()


plt.show()
